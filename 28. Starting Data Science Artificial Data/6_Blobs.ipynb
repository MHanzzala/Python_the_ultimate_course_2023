# %%
import matplotlib.pyplot as plt
import numpy as np

def addOutlier(l, outlier):
    l=list(l)
    for item in outlier:
        l.append(item)
    return l

rng = np.random.RandomState()


x = 10*rng.rand(50)
y = 2*x*x*x -x*x+x +  rng.rand(50)
outlierX=[0.2,4,8, 9]
outlierY=[5,2.5,17.5, 2.7]

x= addOutlier(x,outlierX)
y= addOutlier(y,outlierY)
plt.scatter(x,y)

# %%
print(x)
# Out:
# [1.36534940171686, 4.645172139557224, 2.708153648775565, 6.036652729691227, 4.4402231022528404, 7.543210848488026, 0.06326441567367391, 3.640721798872116, 8.937153056897316, 2.1210899309346596, 0.21427378533009356, 3.0052509964285887, 8.212001940922908, 3.6783381477925303, 5.851484368511262, 9.801576760446869, 3.140863733502978, 4.4715235703245515, 1.3747025911795097, 2.7564974984834976, 0.038547526644184815, 6.323233408692285, 5.3997616607639545, 8.245196096285992, 2.376942629345743, 2.9336528429917417, 6.789538626067242, 5.376850984064101, 3.6767503949108304, 0.7533488159772217, 4.643666121193167, 8.2750757737906, 2.12094119239429, 7.596218532777806, 8.09876020956009, 9.914893211727476, 1.7248827666153754, 8.451819238357615, 4.604827404545869, 4.340548321956962, 5.129778349230615, 5.3362432124796735, 8.996513420727025, 1.8335747388954338, 3.068332494004007, 8.527466981363697, 7.418611818189228, 4.208020189382288, 9.630245230470413, 4.914358443849691, 0.2, 4, 8, 9]

# %%
from sklearn.datasets import make_blobs

# %%
x,y = make_blobs(100, centers=2, random_state=2, cluster_std=8)
plt.scatter(x[:,0],x[:,1], c=y, cmap='RdBu')
