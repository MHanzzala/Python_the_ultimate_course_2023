# %%
import matplotlib.pyplot as plt
import numpy as np


def addOutlier(l, outlier):
    l = list(l)
    for item in outlier:
        l.append(item)
    return l


rng = np.random.RandomState()


x = 10*rng.rand(50)
y = 3*x + rng.rand(50)

outlierX = [0.2, 4, 8, 9]
outlierY = [5, 2.5, 17.5, 2.7]

x = addOutlier(x, outlierX)
y = addOutlier(y, outlierY)
plt.scatter(x, y)
plt.scatter(outlierX, outlierY, color="red")

# %%
print(x)
# Out:
# [0.2651822093570222, 6.939745773022922, 0.3982198597796427, 1.0129046938316844, 5.553603696374556, 0.37909420252300263, 7.535130300868543, 9.093119708455465, 0.12160478043501621, 9.816974076038555, 0.2327133617327959, 5.320206365469051, 4.99853859425156, 7.789883627043671, 0.9526473159265347, 9.248234597396687, 3.168110400565908, 4.7093214570665785, 8.361816679248854, 1.9828673269677333, 4.468655281964828, 8.55005586502098, 9.823037860949288, 2.924755177411117, 4.3136783049780805, 1.2612039906009131, 9.816520571479577, 2.5270650706156053, 6.502049008378174, 8.809283941453828, 0.3162894312736142, 4.911062050555585, 3.081445541525605, 5.991670961670347, 5.573693653192267, 9.414787600968925, 0.5905483987565285, 7.415432153609416, 2.197206296344427, 1.5964217641055134, 7.3685521469214486, 3.203879120791754, 6.532705730565986, 9.975478695024702, 5.703751518430095, 2.7290954405891443, 1.4946993918087714, 2.441125667736306, 6.055404838796422, 6.842529523375954, 0.2, 4, 8, 9]
